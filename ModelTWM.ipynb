# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#dane2019, eksport
import pandas as pd
import numpy as np
from IPython.core.display import HTML

# %%
df = pd.read_excel('Dane_uporządkowane.xlsx')

# %%
df['ltrade'] = np.log(df['trade'])
df['ldistance'] = np.log(df['distance'])
df['lgdp_1'] = np.log(df['gdp_1']/1000000)
df['lgdp_2'] = np.log(df['gdp_2']/1000000)
df['lgdp_2sq'] = df['lgdp_2']*df['lgdp_2']

# %%
df.tail(10)
#ltrade - logarytm wartość eksportu w 2019 roku 
#ldistance - logarytm dystans pomiędzy miastami z największą populacją (km)
#lgdp_1 - logarytm pkb kraju eksportującego w tys $ (teraz jest w miliardach)
#lgdp2 - logarytm pkb kraju importującego w tys$ (teraz jest w miliardach)
#border - granica (1-wspólna granica, 0-w p.p.)
#language - kraje mają wspólny oficjalny język (1-wspólny język, 0-w p.p.)
#religion - indeks religijności (zmienna ciągła w przedziale 0-1)
#colony - czy kraje były w relacji kolonialnej (1-były, 0-nie były)
#legal - podobny system prawny, 1 if countries share common legal origins after 1991
# Out:
#       ReporterName      PartnerName         trade  distance  border  language  \
# 207  United States   Czech Republic  1.751091e+06      6588       0         0
# 208  United States          Estonia  2.652833e+05      6668       0         0
# 209  United States   United Kingdom  4.988196e+07      5585       0         1
# 210  United States            Japan  5.964498e+07     10872       0         0
# 211  United States           Mexico  1.846614e+08      3359       1         0
# 212  United States         Mongolia  1.212179e+05     10186       0         0
# 213  United States           Panama  6.429400e+06      3556       0         0
# 214  United States           Poland  3.767766e+06      6872       0         0
# 215  United States         Portugal  1.274391e+06      5435       0         0
# 216  United States  Slovak Republic  2.561202e+05      6865       0         0
#
#      colony  legal  religion  Wspólny kolonizator  ...  wto_o  wto_d  eu_o  \
# ...

# %%
c=df.groupby('legal')

# %%
c.describe()
# Out:
#        trade                                                       \
#        count          mean           std        min           25%
# legal
# 0      154.0  7.617244e+06  1.997987e+07      2.000  157318.50125
# 1       63.0  1.357342e+07  3.701604e+07  18948.365  533342.73450
#
#                                               distance               ...  \
#                50%          75%           max    count         mean  ...
# legal                                                                ...
# 0      1074291.048  6278175.247  1.846614e+08    154.0  7138.662338  ...
# 1      1540607.478  7262283.308  2.244404e+08     63.0  5854.793651  ...
#
#          lgdp_2           lgdp_2sq                                             \
#             75%       max    count       mean        std       min        25%
# legal
# 0      7.462798  9.566611    154.0  39.528794  24.735638  7.042069  17.917272
# 1      7.146303  9.566611     63.0  37.245751  22.017108  7.042069  17.917272
#
#
# ...

# %%
df.dtypes
# Out:
# ReporterName            object
# PartnerName             object
# trade                  float64
# distance                 int64
# border                   int64
# language                 int64
# colony                   int64
# legal                    int64
# religion               float64
# Wspólny kolonizator      int64
# gdp_1                  float64
# gdp_2                  float64
# gatt_o                   int64
# gatt_d                   int64
# wto_o                    int64
# wto_d                    int64
# eu_o                     int64
# eu_d                     int64
# wto                      int64
# ltrade                 float64
# ldistance              float64
# lgdp_1                 float64
# lgdp_2                 float64
# ldgp_2sq               float64
# dtype: object

# %%
df['trade'].describe()
# Out:
# count    2.170000e+02
# mean     9.346456e+06
# std      2.614194e+07
# min      2.000000e+00
# 25%      2.097997e+05
# 50%      1.207683e+06
# 75%      6.575952e+06
# max      2.244404e+08
# Name: trade, dtype: float64

# %%
import pylab as plt

# %%
plt.hist(df['trade'], bins = 20, edgecolor = 'black')
plt.show()

# %%
print(df[['ltrade', 'ldistance', 'lgdp_1' , 'lgdp_2']].describe().round(2))
# Out:
#        ltrade  ldistance  lgdp_1  lgdp_2
# count  217.00     217.00  217.00  217.00
# mean    13.70       8.43    7.21    5.92
# std      2.89       1.06    1.27    1.95
# min      0.69       5.16    5.53    2.65
# 25%     12.25       7.53    6.12    4.23
# 50%     14.00       8.85    6.81    5.53
# 75%     15.70       9.17    7.91    7.46
# max     19.23       9.88    9.97    9.57

# %%
plt.hist(df['ldistance'], color = 'steelblue', edgecolor = 'black', bins = 20)
plt.show()

# %%
plt.hist(df['lgdp_1'], color = 'steelblue', edgecolor = 'black', bins = 20)
plt.show()

# %%
plt.hist(df['lgdp_2'], color = 'steelblue', edgecolor = 'black', bins = 20)
plt.show()

# %%
plt.hist(df['ltrade'], color = 'steelblue', edgecolor = 'black', bins = 20)
plt.show()

# %%
plt.plot(df['trade'], df['gdp_1'], 'o')
plt.show()

# %%
plt.plot(df['ltrade'], df['lgdp_1'], 'o')
plt.show()

# %%
plt.plot(df['ltrade'], df['lgdp_2'], 'o')
plt.show()

# %%
plt.plot(df['lgdp_2'], df['ltrade'], 'o')
plt.show()

# %%
sns.regplot(x = 'lgdp_2', y = 'ltrade', data = df, ci = None, order = 1)
# Out:
# <Axes: xlabel='lgdp_2', ylabel='ltrade'>

# %%
df.head()
# Out:
#   ReporterName     PartnerName        trade  distance  border  language  \
# 0    Argentina         Belgium   204171.783     11282       0         0
# 1    Argentina        Bulgaria    26542.392     11919       0         0
# 2    Argentina          Canada   557429.590      8930       0         0
# 3    Argentina           China  6340239.209     19629       0         0
# 4    Argentina  Czech Republic    12843.531     11791       0         0
#
#    colony  legal  religion  Wspólny kolonizator  ...  wto_o  wto_d  eu_o  \
# 0       0      1     0.825                    0  ...      1      1     0
# 1       0      0     0.005                    0  ...      1      1     0
# 2       0      0     0.435                    0  ...      1      1     0
# 3       0      0     0.000                    0  ...      1      1     0
# 4       0      0     0.360                    0  ...      1      1     0
#
#    eu_d  wto     ltrade  ldistance    lgdp_1    lgdp_2   ldgp_2sq
# ...

# %%
import seaborn as sns

# %%
plt.plot(df['ldistance'], df['ltrade'], 'o')
plt.show()

# %%
sns.regplot(x='ldistance', y = 'ltrade', data = df, ci = None, order = 1)
#nie uwzględniam religii bez sensu zbyt mały wpływ na zmienną objaśnianą
# Out:
# <Axes: xlabel='ldistance', ylabel='ltrade'>

# %%
plt.plot(df['religion']*100, df['ltrade'], 'o')
plt.show()

# %%
df.head()
# Out:
#   ReporterName     PartnerName        trade  distance  border  language  \
# 0    Argentina         Belgium   204171.783     11282       0         0
# 1    Argentina        Bulgaria    26542.392     11919       0         0
# 2    Argentina          Canada   557429.590      8930       0         0
# 3    Argentina           China  6340239.209     19629       0         0
# 4    Argentina  Czech Republic    12843.531     11791       0         0
#
#    colony  legal  religion  Wspólny kolonizator  ...  wto_o  wto_d  eu_o  \
# 0       0      1     0.825                    0  ...      1      1     0
# 1       0      0     0.005                    0  ...      1      1     0
# 2       0      0     0.435                    0  ...      1      1     0
# 3       0      0     0.000                    0  ...      1      1     0
# 4       0      0     0.360                    0  ...      1      1     0
#
#    eu_d  wto     ltrade  ldistance    lgdp_1    lgdp_2   ldgp_2sq
# ...

# %%
df_ciagle = df[['ltrade', 'ldistance', 'lgdp_1', 'lgdp_2']]

# %%
df_ciagle.corr(method = 'spearman')
# Out:
#              ltrade  ldistance    lgdp_1    lgdp_2
# ltrade     1.000000  -0.312377  0.378074  0.633652
# ldistance -0.312377   1.000000  0.018986  0.146257
# lgdp_1     0.378074   0.018986  1.000000 -0.024504
# lgdp_2     0.633652   0.146257 -0.024504  1.000000

# %%
sns.heatmap(df_ciagle.corr(method = 'spearman'), vmin = -1, vmax  = 1, cmap = 'coolwarm')
#zmienne objaśniające nie są mocno skorelowane,
# Out:
# <Axes: >

# %%
df_ciagle_zo = df[['ltrade', 'ldistance', 'lgdp_1', 'lgdp_2','wto', 'language', 'colony', 'legal', 'border']]

# %%
plt.plot(x='ldistance', y = 'ltrade', data = df, ci = None )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[268], line 1
# ----> 1 plt.plot(x='ldistance', y = 'ltrade', data = df, ci = None )
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2785, in plot(scalex, scaley, data, *args, **kwargs)
#    2783 @_copy_docstring_and_deprecators(Axes.plot)
#    2784 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2785     return gca().plot(
#    2786         *args, scalex=scalex, scaley=scaley,
#    2787         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
# ...

# %%
sns.pairplot(df_ciagle_zo, hue = 'legal')

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm
import statsmodels.stats.api as sms

# %%
m1 = smf.ols(formula = 'ltrade ~ ldistance + lgdp_1 + lgdp_2 + language + colony + legal + border+religion', data = df).fit()
m1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 ltrade   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     111.2
# Date:                Sun, 14 Jan 2024   Prob (F-statistic):           8.14e-71
# Time:                        14:15:13   Log-Likelihood:                -357.40
# No. Observations:                 217   AIC:                             732.8
# Df Residuals:                     208   BIC:                             763.2
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     10.6595      0.956     11.154      0.000       8.775      12.543
# ...

# %%
hip1 = '(colony = 0)'
m1.f_test(hip1)
# Out:
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <F test: F=0.042417448951818135, p=0.8370275288536588, df_denom=208, df_num=1>

# %%
m2 = smf.ols(formula = 'ltrade ~ ldistance + lgdp_1 + lgdp_2 + language + legal + border + religion', data = df).fit()
m2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 ltrade   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     127.6
# Date:                Sun, 14 Jan 2024   Prob (F-statistic):           7.09e-72
# Time:                        14:15:13   Log-Likelihood:                -357.42
# No. Observations:                 217   AIC:                             730.8
# Df Residuals:                     209   BIC:                             757.9
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     10.6754      0.950     11.234      0.000       8.802      12.549
# ...

# %%
hip2 = '(colony = 0), (border = 0)'
m1.f_test(hip2)
# Out:
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <F test: F=0.16139264729850059, p=0.8510643401467503, df_denom=208, df_num=2>

# %%
m3 = smf.ols(formula = 'ltrade ~ ldistance + lgdp_1 + lgdp_2 + legal + religion+language', data = df).fit()
m3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 ltrade   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     149.4
# Date:                Sun, 14 Jan 2024   Prob (F-statistic):           6.39e-73
# Time:                        14:15:13   Log-Likelihood:                -357.56
# No. Observations:                 217   AIC:                             729.1
# Df Residuals:                     210   BIC:                             752.8
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     10.8490      0.891     12.180      0.000       9.093      12.605
# ...

# %%
hip3 = '(colony = 0), (border = 0),(religion = 0)'
m1.f_test(hip3)
# Out:
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <F test: F=0.22109607800217715, p=0.8816787343867601, df_denom=208, df_num=3>

# %%
m4 = smf.ols(formula = 'ltrade ~ ldistance + lgdp_1 + lgdp_2 + legal + religion', data = df).fit()
m4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 ltrade   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     179.6
# Date:                Sun, 14 Jan 2024   Prob (F-statistic):           5.82e-74
# Time:                        14:15:13   Log-Likelihood:                -357.83
# No. Observations:                 217   AIC:                             727.7
# Df Residuals:                     211   BIC:                             747.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     10.8944      0.887     12.277      0.000       9.145      12.644
# ...

# %%
hip4 = '(colony = 0), (border = 0),(religion = 0), (language = 0)'
m1.f_test(hip4)
# Out:
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <F test: F=0.25835408161132045, p=0.9043198565661555, df_denom=208, df_num=4>

# %%
m5 = smf.ols(formula = 'ltrade ~ ldistance + lgdp_1 + lgdp_2 + legal', data = df).fit()
m5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 ltrade   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     225.2
# Date:                Sun, 14 Jan 2024   Prob (F-statistic):           4.04e-75
# Time:                        14:15:13   Log-Likelihood:                -357.93
# No. Observations:                 217   AIC:                             725.9
# Df Residuals:                     212   BIC:                             742.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     11.0111      0.849     12.973      0.000       9.338      12.684
# ...

# %%
# !pip install stargazer
from stargazer.stargazer import Stargazer
from IPython.core.display import HTML
from statsmodels.iolib.summary2 import summary_col

# %%
stargazer = Stargazer([m1, m2, m3, m4, m5])
stargazer
# Out:
# <table style="text-align:center"><tr><td colspan="6" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="5"><em>Dependent variable: ltrade</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td></tr>
# <tr><td colspan="6" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">Intercept</td><td>10.659<sup>***</sup></td><td>10.675<sup>***</sup></td><td>10.849<sup>***</sup></td><td>10.894<sup>***</sup></td><td>11.011<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.956)</td><td>(0.950)</td><td>(0.891)</td><td>(0.887)</td><td>(0.849)</td></tr>
# <tr><td style="text-align:left">border</td><td>0.247<sup></sup></td><td>0.240<sup></sup></td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left"></td><td>(0.455)</td><td>(0.453)</td><td></td><td></td><td></td></tr>
# ...

# %%
c.as_html()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[368], line 1
# ----> 1 c.as_html()
#
# AttributeError: 'HTML' object has no attribute 'as_html'

# %%
#analiza obserwacji nietypowych 
sm.graphics.influence_plot(m5, criterion = 'Cooks')
plt.show()

# %%
h_lev = (2*len(m5.params))/m5.nobs
round(h_lev, 2)
# Out:
# 0.05

# %%
sm.graphics.influence_plot(m5, criterion = 'Cooks', )
plt.axvline(x = round(h_lev, 2), color = 'g')
plt.axhline(y=2, color = 'r')
plt.axhline(y=-2, color = 'r')
plt.show()

# %%
#współliniowość
def get_vif(exogs, data):
    # initialize dictionaries
    vif_dict, tolerance_dict = {}, {}

    # create formula for each exogenous variable
    for exog in exogs:
        not_exog = [i for i in exogs if i != exog]
        formula = f"{exog} ~ {' + '.join(not_exog)}"

        # extract r-squared from the fit
        r_squared = smf.ols(formula, data=data).fit().rsquared

        # calculate VIF
        vif = 1/(1 - r_squared)
        vif_dict[exog] = vif

        # calculate tolerance
        tolerance = 1 - r_squared
        tolerance_dict[exog] = tolerance

    # return VIF DataFrame
    df_vif = pd.DataFrame({'VIF': vif_dict, 'Tolerance': tolerance_dict})

    return df_vif

# %%
m5.params
# Out:
# Intercept    11.011116
# ldistance    -1.333230
# lgdp_1        1.047367
# lgdp_2        1.034905
# legal         0.834154
# dtype: float64

# %%
zmienne = ['ldistance', 'lgdp_1', 'lgdp_2']

# %%
get_vif(exogs = zmienne, data = df)
# Out:
#                 VIF  Tolerance
# ldistance  1.029813   0.971050
# lgdp_1     1.013374   0.986802
# lgdp_2     1.018578   0.981761

# %%
#testowanie założeń KRML
sm.graphics.plot_partregress_grid(m5)
# Out:
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1

# %%
#forma funkcyjna
sms.linear_reset(m5, power = 3, test_type = 'fitted')
# Out:
# C:\Users\Mariusz\anaconda3\lib\site-packages\statsmodels\stats\diagnostic.py:1081: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   aug = res.fittedvalues[:, None]
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <Wald test (chi2): statistic=49.08705666978756, p-value=2.1922045646939923e-11, df_denom=2>

# %%
#Homoskedastyczność
plt.scatter(m5.fittedvalues, m5.resid)
plt.axhline(y = 0, color = 'red')
plt.axhline(y=0 + 3*m5.resid.std(), color = 'green')
plt.axhline(y=0 - 3*m5.resid.std(), color = 'green')
plt.xlabel('fitted values')
plt.ylabel('residuals')
plt.show()

# %%
test1 = sms.het_breuschpagan(m5.resid, m5.model.exog)
test1
# Out:
# (12.23748886143069,
#  0.015669908452549362,
#  3.167508085583632,
#  0.01484333837546062)

# %%
from statsmodels.compat import lzip

# %%
nam1 = ['lagrange multiplier statistic', 'p-value', 'f-value', 'f p-value']

# %%
lzip(nam1, test1)
# Out:
# [('lagrange multiplier statistic', 12.23748886143069),
#  ('p-value', 0.015669908452549362),
#  ('f-value', 3.167508085583632),
#  ('f p-value', 0.01484333837546062)]

# %%
test2 = sms.het_white(m5.resid, m5.model.exog)
test2
# Out:
# (37.189351464289466,
#  0.0003869118500833733,
#  3.22965314591068,
#  0.0001875381415785893)

# %%
lzip(nam1, test2)
# Out:
# [('lagrange multiplier statistic', 37.189351464289466),
#  ('p-value', 0.0003869118500833733),
#  ('f-value', 3.22965314591068),
#  ('f p-value', 0.0001875381415785893)]

# %%
#normalność składanika losowego 
plt.hist(m5.resid, bins = 20, color = 'orange', edgecolor = 'black')
plt.show()

# %%
sm.qqplot(m5.resid, line = 'r')
plt.show()

# %%
test3 = sms.jarque_bera(m5.resid)
test3
# Out:
# (523.0273672458957,
#  2.6671673146217786e-114,
#  -1.4905463049853958,
#  9.997101658208244)

# %%
nam2 = ['The Jarque-Bera test statistic', 'p-value', 'skewness', 'kurtosis']

# %%
lzip(nam2, test3)
# Out:
# [('The Jarque-Bera test statistic', 523.0273672458957),
#  ('p-value', 2.6671673146217786e-114),
#  ('skewness', -1.4905463049853958),
#  ('kurtosis', 9.997101658208244)]

# %%
#brak autokorelacji reszt
test4 = sms.acorr_breusch_godfrey(m5)
test4
# Out:
# (14.53242134996437,
#  0.15006145433360651,
#  1.449886017438321,
#  0.16075013113621198)

# %%
m6 = smf.ols(formula = 'ltrade ~ ldistance + lgdp_1  + legal +  lgdp_2', data = df).fit()
m6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 ltrade   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.825
# Method:                 Least Squares   F-statistic:                     170.5
# Date:                Sun, 14 Jan 2024   Prob (F-statistic):           7.69e-78
# Time:                        15:20:08   Log-Likelihood:                -345.81
# No. Observations:                 217   AIC:                             705.6
# Df Residuals:                     210   BIC:                             729.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
sms.linear_reset(m5, power = 3, test_type = 'exog')
# Out:
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <Wald test (chi2): statistic=6.708147228067542, p-value=0.3486827200651849, df_denom=6>

# %%
sns.lmplot(x = 'lgdp_2', y = 'ltrade', data = df, ci = None, hue = 'legal')
plt.show()
